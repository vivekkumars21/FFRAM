# %% [markdown]
# # Data Visualization using Matplotlib, Seabon, Ploty

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x**2
print(x,y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ] [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x,y)
plt.title("Square Of Values")
plt.xlabel("Values")
plt.ylabel("Squares")
# Out:
# Text(0, 0.5, 'Squares')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,y)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(y**2,x)

# %%
fig = plt.figure(figsize=(16,9),dpi=100)
axis1 = fig.add_axes([0.1,0.1,.8,.8])

axis1 = axis1.plot(x,y)
plt.title("hello")
plt.xlabel("Name")
axis2 = fig.add_axes([.3,.3,.5,.5])
axis2.plot(x,y)
axis2 = plt.xlabel("Velle")

# %%
from random import sample
data = sample(range(0,1000),100)
plt.hist(data)
# Out:
# (array([14., 11.,  9.,  9., 14.,  9.,  9.,  4., 10., 11.]),
#  array([  7. , 105.9, 204.8, 303.7, 402.6, 501.5, 600.4, 699.3, 798.2,
#         897.1, 996. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x,y)

# %% [markdown]
# save PLOT

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,.8,.8])
ax.plot(x,y)
plt.xlabel("number")
plt.ylabel("square")
plt.title("Square OF numbers")
plt.savefig("BASIC PLOT.png")

# %% [markdown]
# Working with image using matplotlib

# %%
import matplotlib.image as mpimg

img = mpimg.imread('image.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1594.5), np.float64(-0.5))

# %%
croppedimg = img[200:500,300:600]
plt.imshow(croppedimg)
