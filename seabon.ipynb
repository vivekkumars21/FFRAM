# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')

# %%
df['size'].unique()

# %%
sns.displot(df['total_bill'],bins = 12,kde = True)

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.jointplot(x = df['total_bill'],y = df['tip'], kind= 'scatter',color = 'white')
